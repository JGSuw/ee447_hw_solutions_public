# %% [markdown]
# # Group work and HW1 due 5p Fri April 9, 2021
#
# You are welcome (and encouraged) to work with others, but each individual must submit their own writeup for the HW portion. We will do the Group work portion in class with your classmates on Wednesdays to get full credit, but you can choose to do that portion individually and submit it along with your hw for a grade (i.e. you will not automatically get full credit).
#
# You are welcome to use analytical and numerical computational tools; if you do, include the **commented** sourcecode in your submission (e.g. the .ipynb file) as a link to your Colaboratory notebook or upload your .ipynb notebook if you used Jupyter Notebook. This is in addition to the PDF that you create.
#
# You are welcome to consult websites, textbooks, and other materials; if you do, include a full citation in your writeup (e.g. the .ipynb file).
#
# **Important:** before you do any work in the Colaboratory notebook, click "File -> Save a copy in Drive ..." and rename the file to something memorable.
#
# **Also important:** To produce a .pdf for submission to Canvas, click "File -> Print" (or press Ctrl/Cmd + P), and choose "Save to PDF" or "Microsoft Print to PDF" as your printer. Don't forget to include the link to your Colaboratory notebook or upload your .ipynb file if you used Jupyter notebook

# %% [markdown]
# # Group work -- Wed April 7
#
# I encourage you to attend the group work session on Wednesdays to complete the group work portion of your homework -- you will get full credit as long as you participate and make an effort on the problem. This is also a great opportunity to get to know your classmates. Only one person needs to submit.
#
# Please note that only one person can edit the Colaboratory notebook at a time, I recommend creating a copy for yourself and copy pasting your solutions in the discord or Zoom chat if people want to work on different parts of the writeup.

# %% [markdown]
# ## 1. Groupmates: [Names of everyone in your group]

# %% [markdown]
# ## 2. [15 min]: Virtual learning
#
# Part 1, Virtual learning [15 minutes]: Check in with your classmates about how virtual learning is going for you. Now that it has been over a year since virtual learning started, are there any tips that you could share with the group about how to deal with the challenges of virtual learning? Is there anything about virtual learning that you prefer over learning in-person? You do not need to disclose these details in this notebook unless you want to, though I always love hearing about how things are going for you (so you are most definitely invited to share!) As a group, pick one piece of advice you would give to people starting virtual learning (or teaching!) for the first time, or describe something that is working well for you (and put that in your Colaboratory notebook).

# %% [markdown]
# ## 3. [20 min] Feedback control systems
#
# Describe two different feedback control systems in your everyday life. Please format your answer nicely in Markdown so that we can easily grade it.
# - Describe the process or plant. What are its inputs and what are its outputs?
# - What is the goal of the feedback system?
# - How is the controller implemented (electronically, with a microcontroller, etc)?
# - What are potential disturbances to the plant that the controller must account for?
# - What are potential sources of noise in the sensor?
# - What is the reference input, if any, supplied by the user?
# - What do you suppose are the most important performance requirements for the system (speed, robustness, disturbance rejection, cost)?
#
# ---
# **Solution**
# An example feedback system is a central heating system for a home, which maintains the interior temperature of a house.
#
# - The process or plant consists of the volume of air int the home and its ventillation. The input to the plant is *air flow* at some *temperature*. The output of the process or plant is the interior temperature of the home.
# - The feedback system consists of the central heating system, the goal of this feedback system is to maintain the interior temperature of the house.
# - The controller is implemented with electronics to measure the temperature of the air in the home, the temperature of the air in the heater, and to control the fans and power in the heater.
# - One potential disturbance to the plant would be an open window or door, which changes the ventillation of the house and the rate of *cold air* entering the house.
# - The thermostat could be located near an appliance that generates heat, or otherwise is placed in an area that *locally* has a different temperature from the average temperature in the house.
# - The reference input is the desired temperature in the house.
# - The most important performance requirement for heating the home is *efficiency*, because the primary cost incurred by the using is the cost of energy to run the heater. This affects both 1) the design of the heating system but also 2) the design of the plant (the home, its windows, etc).
# ---

# %% [markdown]
# ## 4.  [30 min] Simulation of DE
#
# Use this script in the following problem and for the simulation of DE cont. problem in the homework -- it computes a numerical approximation to the solution of the following (DE):
# $$\dot{y} + a y = b u.$$
# (If you're curious about where the script came from, read the explanation that appears at the end of the homework below.)

# %%
import numpy as np
import pylab as plt # pylab == matplotlib.pyplot
# %matplotlib inline

# DE parameters
a = 1.
b = 1.

# initial value, final time, timestep
y0 = 1.
t = 20.
dt = 1e-2

# time points -- multiples of dt from 0 to t
T = np.arange(0,t,dt)

# input
def u(s):
  return np.sin(s)

y = [y0] # output
for s in T[:-1]: # loop through times; exlude final time
  y.append(y[-1] + dt * (-a*y[-1] + b*u(s))) # DE
y = np.array(y)

plt.subplot(2,1,1)
plt.plot(T,y)
plt.ylabel(r'output ($y$)')
plt.xticks([]) # remove "ticks" on the x-axis

plt.subplot(2,1,2)
plt.plot(T,u(T))
plt.ylabel(r'input ($u$)')
plt.xlabel(r'time ($t$)')
plt.tight_layout() # adjusts sizes and locations

pass

# %% [markdown]
# a. With $u(s) = 0$, simulate the DE twice:  first with $y_1(0) = 1$ to obtain numerical simulation $\tilde{y}_1$ and second with $y_3(0) = 3$ to obtain numerical simulation $\tilde{y}_3$.  Show that $\tilde{y}_3 = 3 \tilde{y}_1$ by plotting $\tilde{y}_3$ and $3 \tilde{y}_1$ on the same axis using the following code snippet.
#
# ***Note:*** the code snippet below includes informative axis labels and a legend on the plot, and uses different a different line style / width for the second line to distinguish it from the first -- ***all plots you create in this course should have similarly informative labels (and legends, as applicable), and make use of different line styles / widths to distinguish lines.***  Unabeled or otherwise uninterpretable plots will not be graded for credit.

# %%
# code for problem (a.) goes herey1 = [1.]
y3 = [3.]
for s in T[1:]:
    y1.append(y1[-1]+dt*(-a*y1[-1]+b*0))
    y3.append(y3[-1]+dt*(-a*y3[-1]+b*0))
y1 = np.array(y1)
y3 = np.array(y3)

# %%
# code snippet for plotting in problem (a.)
y1 = np.array(y1) # convert Python list y1 to NumPy array
plt.plot(T,3*y1,label=r'$y_1$') # label this line for inclusion in a legend
plt.plot(T,y3.real,label=r'$y_3$',linestyle='--',linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend() # adds legend using label's specified in plot(...) command

# %% [markdown]
# ### * end of group work -- download as PDF and submit as part of group assignment *

# %% [markdown]
# # HW 1
#
# Please write up and submit this portion individually

# %% [markdown]
# # 0. [preferred name]; [preferred pronouns]
#
# a. Approximately how many hours did you spend on this assignment?
#
# b. Were there specific problems that took much longer than others?
#
# c. What class meeting(s) did you participate in this week?
#
# d. What timezone(s) were you working in this week?

# %% [markdown]
# # 1. LaTeX
#
# ***Purpose:*** learn how to format text cells using LaTeX
#
# Copy the following definition into Markdown.  Note that even single letter equations like $A$ and $v$ are in math mode and that the terms being defined are italicized.
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ---
# **SOLUTION**
# ```
# Let $A$ be a linear transformation represented by matrix $A$. If there is a vector $v \in \mathbb{R}^n \neq 0 $ s. t.
#
# $$Av=\lambda v $$
#
# for some scalar $\lambda$, then $\lambda$ is called the *eigenvalue* of $A$ with corresponding (right) *eigenvector* $v$
# ```
#
# ---

# %% [markdown]
# # 2. control systems
#
# ***Purpose:*** apply control systems concepts and terminology in real-world examples and applications.
#
# a,b. Read Chapter 1 of the Astrom / Murray v2 textbook [[AMv2]](http://www.cds.caltech.edu/~murray/amwiki/index.php/Second_Edition), and report your solutions to Exercises 2 and 3 from Chapter 1.

# %% [markdown]
# 1.2 (Balance systems) Balance yourself on one foot with your eyes closed for 15 s. Using Figure 1.3 as a
# guide, describe the control system responsible for keeping you from falling down. Note that the “controller”
# will differ from that in the diagram (unless you are an android reading this in the far future).*
#
# ---
# **Solution:** We will describe each part of the control systemusing the labels of Figure 1.3.
#
# Noise: This is the noise that enters the system between the computer and the actuators. For the human body, this could be noise that enters along the neural pathway, due to the stochastic nature of neural signaling.
#
# Actuators: The actuators for keeping balance are the feet muscles and possibly the arms.
#
# System: The system is your body balanced on top of your legs and feet.
#
# External Disturbances: This would be anything that effects the system that we do not have control over, like air currents or the stability of the ground.
#
# Sensors: The sensors of for this problem is the fluid in your inner ear, and your sense of touch on the ground.
#
# Noise: This is the noise that enters the system as a result of the sensing process. For the human body, this
# could be the imperfections in the sensing equipment (like diseases effecting your inner ear or your sense of touch) or neural pathway from the senses to the brain.
#
# Computer: The human brain that processes the signals generated by your body and sends out the commands to correct for any balance problems.
#
# Operator Input: The human's intention / will to remain balanced.
#
# ---
#
# *1.3 (Eye motion) Perform the following experiment and explain your results: Holding your head still, move one of your hands left and right in front of your face, following it with your eyes. Record how quickly you can move your hand before you begin to lose track of it. Now hold your hand still and shake your head left to right, once again recording how quickly you can move before losing track of your hand.*
#
# ---
#
# **Solution:** The experiment shows that it is easier to track fast if the hand is fixed. The reason is due to the properties of the feedback systems. When the head is moved there are gyroscopic sensors for angular rate that sends signals directly to the eyes to keep the line of sight constant. When the head is kept fixed and the eyes are moving, it takes more time because the information about the image has to be processed in the brain before signals can be sent to the eyes to move them.
#
# ---

# %% [markdown]
# # 3. proportional-integral control
#
# This problem considers the following standard negative feedback block diagram.
#
# ![negative feedback block diagram](http://faculty.washington.edu/sburden/447/447-hw1-feedback.png)
#
# ***Purpose:*** you will analyze and synthesize a ***proportional-integral*** controller
# $$ C(s) = k_P + k_I/s \iff u(t) = k_P e(t) + k_I \int_0^t e(\tau) d\tau $$
# for the purpose of ***reference tracking*** (*not* disturbance rejection, which we covered in lecture) in the presence of ***unmodeled dynamics***.
#
# first-order process
# --
#
# First, you will apply the proportional-integral controller to a ***first-order*** process model $P(s) = b / (s + a)$.
#
# a. Determine the transfer function $G_{yr}$; simplify your formula until $G_{yr}$ is a rational function.  (***Note:***  we focused on $G_{yv}$ in lecture, not $G_{yr}$; however, we did derive the general formula for $G_{yr}$, which you can use to solve this problem. Once you have found $G_{yr}$ in terms of $P,C$ using block diagram algebra, you can use computational tools to get $G_{yr}$ in terms of $k_P, k_I, b, a$)
#
# ---
# **Solution:**
#
# According to the block diagram (omitting $v = 0$):
#
# $$(C(s)(r-y)+v)P(s)=y \iff (PC+1)y=PCr+Pv$$
#
# $$\Rightarrow y= \frac{PC}{1+PC}r$$
# $$\Rightarrow G_{yr}(s) = \frac{P(s)C(s)}{1+P(s)C(s)}$$
# Plug in $P = \frac{b}{s+a}, C = \frac{k_Ps+k_I}{s}$
# $$\Rightarrow G_{yr}(s) = \frac{k_Pbs+k_Ib}{s^2+(a+k_Pb)s+k_Ib}$$
#
# ---
#
#
# b. How does $G_{yr}$ change if the process gain increases by $10\%$ (i.e. what happens if you replace $P$ by $1.1\cdot P$)?  (***Hint:*** the change isn't $10\%$ -- this demonstrates that feedback can reduce the effect of model uncertainty.)
#
# ---
# **Solution:**
#
# If the process gain $P(s)$ increases by $10%$, $G_{yrn}(s)=\frac{1.1P(s)C(s)}{1+1.1P(s)C(s)} = \frac{P(s)C(s)}{\frac{1}{1.1}+P(s)C(s)}$
#
# And if $G_{yr}(s)$ is increased by 10%, we have:
# $ 1.1G_{yr}(s) = \frac{1.1P(s)C(s)}{1+P(s)C(s)}$
#
# Thus, it can be seen that compared to $G_{yr}(s)$, $G_{yrn}(s)$ increases, but less than 10%.
#
# ---
#
# c. Evaluate $G_{yr}(0)$. What does this value imply about ***asymptotic reference tracking***, i.e. if the reference is constant, $r(t) = r_0$, how does $\lim_{t\rightarrow\infty} y(t)$ relate to $r_0$ (assuming the system is stable so $\lim_{t\rightarrow\infty} y(t)$ always exists)?   (***Note:*** $G_{yr}(0)$ is termed the ***static gain***)
#
# ---
# **Solution:**
#
# If $s=0$, $G_{yr}(0)=\frac{k_Ib}{k_Ib}=1$\
# $\lim_{t\rightarrow\infty} y(t) = G_{yr}(0) \cdot r_0  = r_0$
#
# ---
#
# second-order process
# ---
# Now consider the ***second-order*** process model $P(s) = \frac{b}{s^2 + a_1 s + a_2}$.
#
# d. Determine the degree of the numerator and denominator polynomials of $P$ and $C$. (***Hint:*** you need to simplify $C$ until it is a ***rational function***, that is, a ratio of two polynomials.)
#
# ---
# **Solution:**
#
# For $P(s) = \frac{b}{s^2 + a_1 s + a_2}$, degree of the numerator is 0, degree of the and denominator is 2.
#
# For $ C(s) = \frac{k_Ps+k_I}{s}$, degree of the numerator is 1, degree of the and denominator is 1.
#
# ---
#
# e. Determine the degree of the numerator and denominator polynomials of the closed-loop transfer function $G_{yr}$.  (***Hint:*** you need to simplify $G_{yr}$ until it is a ***rational function***, that is, a ratio of two polynomials. Again, you probably want to use computational tools to simplify $G_{yr}$)
#
# ---
# **Solution:**
#
# Recall that $G_{yr}(s) = \frac{P(s)C(s)}{1+P(s)C(s)}$
# Plug in $P(s)$ and $C(s)$,
# $$G_{yr}(s) = \frac{\frac{k_Pbs+k_Ib}{s^3+a_1s^2+a_2s}}{1 + \frac{k_Pbs+k_Ib}{s^3+a_1s^2+a_2s}}$$
# $$\Rightarrow G_{yr}(s) = \frac{k_Pbs+k_Ib}{s^3+a_1s^2+(a_2+k_Pb)s+k_Ib}$$
# It can be seen that the degree of the numerator is 1, degree of the and denominator is 3.
#
# ---
#
# ***Takeaway:*** the integral term in the proportional-integral controller introduces new dynamics to the system that increases the dynamical complexity (as measured by the degree of the characteristic polynomial of $G_{yr}$(s) of the closed-loop system.

# %% [markdown]
# # 4. simulation of DE cont.
#
# ***Purpose:*** computationally verify that the solution of a differential equation is a linear combination of the ***homogeneous*** and ***particular*** solutions.
#
# For helpful code, look at the example code provided in "simulation of DE" problem in the group work section

# %% [markdown]
# a. With $y(0) = 0$, simulate the DE three times:  first with $u_{\sin}(t) = \sin(t)$ to obtain simulation $\tilde{y}_{\sin}$, second with $u_{\cos}(t) = \cos(t)$ to obtain simulation $\tilde{y}_{\cos}$, and third with $u_{\sin+\cos}(t) = \sin(t) + \cos(t)$ to obtain solution $\tilde{y}_{\sin+\cos}$.  Show that $\tilde{y}_{\sin+\cos} = \tilde{y}_{\sin} + \tilde{y}_{\cos}$ by plotting $\tilde{y}_{\sin+\cos}$ and $\tilde{y}_{\sin} + \tilde{y}_{\cos}$ on the same axis.  Vary the line style/width and include a legend as in the previous problem to make it easy to visually distinguish the two lines.

# %%
import numpy as np
import pylab as plt # pylab == matplotlib.pyplot

def simulate_y(y0, u, T, dt, a, b):
  y = [y0] # output
  for s in T[:-1]: # loop through times; exlude final time
    y.append(y[-1] + dt * (-a*y[-1] + b*u(s))) # DE
  return y

# DE parameters
a = 1.
b = 1.

# initial value, final time, timestep
y0 = 1.
t = 20.
dt = 1e-2

# time points -- multiples of dt from 0 to t
T = np.arange(0,t,dt)

#inputs
u_sin = lambda s: np.sin(s)
u_cos = lambda s: np.cos(s)
u_sin_cos = lambda s: np.sin(s) + np.cos(s)

y0 = 0.

y_sin = simulate_y(y0, u_sin, T, dt, a, b)
y_cos = simulate_y(y0, u_cos, T, dt, a, b)
y_sin_cos = simulate_y(y0, u_sin_cos, T, dt, a, b)


y_sin = np.array(y_sin)
y_cos = np.array(y_cos) 
y_sin_cos = np.array(y_sin_cos) 
plt.plot(T,y_sin + y_cos,label=r'$y_{sin} + y_{cos}$')
plt.plot(T,y_sin_cos,label=r'$y_{sin + cos}$',linestyle='--',linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()

# %% [markdown]
# b. Experiment with at least one of the following and describe how the simulation results change.
# * Increase the timestep $\delta t$ to $0.1$, $1$, or larger.
# * Change the value of $a$, keeping the sign the same.
# * Change the sign of $a$, keeping the value the same.

# %%
# code for problem (b.) goes here


# DE parameters
a = 1.
b = 1.

# initial value, final time, timestep
y0 = 1.
t = 20.
dt = 1

# time points -- multiples of dt from 0 to t
T = np.arange(0,t,dt)

# input
def u(s):
  return np.sin(s)

y = [y0] # output
for s in T[:-1]: # loop through times; exlude final time
  y.append(y[-1] + dt * (-a*y[-1] + b*u(s))) # DE
y = np.array(y)

ycrap=y
Tcrap=T

plt.subplot(2,1,1)
plt.plot(T,y)
plt.ylabel(r'output ($y$)')
plt.xticks([]) # remove "ticks" on the x-axis

plt.subplot(2,1,2)
plt.plot(T,u(T))
plt.ylabel(r'input ($u$)')
plt.xlabel(r'time ($t$)')
plt.tight_layout() # adjusts sizes and locations

# %% [markdown]
# c. Express $u_1(t) = \sin(t)$ and $u_2(t) = \cos(t)$ as complex exponentials.

# %% [markdown]
# ---
# **SOLUTION**
# $$\sin(t) = \frac{e^{jt}-e^{-jt}}{2j}$$
# $$\cos(t) = \frac{e^{jt}+e^{-jt}}{2}$$
#
# ---

# %% [markdown]
# d. Use the transfer function representation of the model specified by (DE) to determine the system's response to the two inputs in (d.) and create a plot to compare with your results from (b.).
#
# **Solution:**\
# The transfer function of the system is:\
# $G(s) = \frac{b}{s+a} = \frac{1}{s+1}$\
# According to 3.d, the output of $u_1$ and $u_2$ is:\
# $y_1(t) = G(s)u_1(t) = \frac{1}{2i}G(i)e^{it}-\frac{1}{2i}G(-i)e^{-it}$\
# $\rightarrow y_1(t) = \frac{1}{2i}*\frac{1}{1+i}e^{it}-\frac{1}{2i}*\frac{1}{1-i}e^{-it}$\
# $y_2(t) = G(s)u_2(t) = \frac{1}{2}G(i)e^{it}+\frac{1}{2}G(-i)e^{-it}$\
# $\rightarrow y_2(t) = \frac{1}{2}*\frac{1}{1+i}e^{it}+\frac{1}{2}*\frac{1}{1-i}e^{-it}$\
# Following is the code to simulate:

# %%
# code for problem (d.) goes here
t = 20.
dt = 1e-2
# time points -- multiples of dt from 0 to t
T = np.arange(0,t,dt)

i = 1j 
y1 = 1/(2*i)/(1+i)*np.exp(i*T) - 1/(2*i)/(1-i)*np.exp(-i*T)
y2 = 0.5/(1+i)*np.exp(i*T) + 0.5/(1-i)*np.exp(-i*T)



plt.plot(T, y1,label=r'$y_1$')
plt.plot(T,y_sin,label=r'$y_{sin}$',linestyle='--',linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()

plt.figure()
plt.plot(T, y2,label=r'$y_2$')
plt.plot(T,y_cos,label=r'$y_{cos}$',linestyle='--',linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()

plt.figure()
plt.plot(T, y1+y2,label=r'$y_1 + y_2$')
plt.plot(T, y_sin_cos, label=r'$y_{sin+cos}$', linestyle='--', linewidth=2) 
plt.xlabel(r'time ($t$)')
plt.ylabel(r'output ($y$)')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ***Where did the simulation script come from?*** If you're interested to understand where the script above came from, read the following explanation.
#
# Consider the ***differential equation***
# $$\dot{y} + a y = b u.$$
#
# If the pair of signals $(u,y)$ are a solution to the differential equation from problem (4.), then they approximately solve the ***difference equation***
#
# $$ \frac{1}{\delta t}(y(t + \delta t) - y(t)) + a y(t) \simeq b u(t); $$
#
# this equation can be derived directly from the definition of the time derivative $\dot{y}$ of the signal $y$.  Rearranging this difference equation, we find the approximation
#
# $$ \tilde{y}[t + \delta t] = \tilde{y}[t] + \delta t ( -a \tilde{y}[t] + b u[t] ). $$
#
# This difference equation can be used to approximate solutions to the original differential equation as follows:
# 0. suppose initial value $y(0)$, input $u:\mathbb{R}\rightarrow\mathbb{R}$, final time $t > 0$, and timestep $\delta t > 0$ are given, and set $k = 0$, $\tilde{y}[0] = y(0)$;
# 1. set $\tilde{y}[(k+1)\cdot\delta t] = \tilde{y}[k\cdot\delta t] + \delta t ( -a \tilde{y}[k\cdot\delta t] + b u[k\cdot\delta t] )$;
# 2. set $k = k+1$;
# 3. if $k\cdot\delta t < t$, go back to step (1.), otherwise stop.
#
# The sequence of values $\tilde{y}[k\cdot\delta t]$ for $k\in\mathbb{N}$ approximate the solution $y(k\cdot\delta t)$ of the original differential equation; when we implement this approximation on a computer, we call $\tilde{y}$ a ***numerical simulation*** of $y$.
#
# Translating the algorithm specified by the pseudocode (0.)--(3.) to Python, we obtain the preceding script.
